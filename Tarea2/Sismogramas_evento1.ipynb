# %% [markdown]
# ## Tarea 2 Sismología

# %% [markdown]
# ### Universidad de Chile

# %% [markdown]
# #### Por: Aura Cuervo

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
import math
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Sismogramas evento 1

# %% [markdown]
# Estación: CX.HMBCX, Fecha y hora: 2011/205 1:53

# %%
datos1e = loadtxt('CX.HMBCX..HHE.D.2011.205.01.53.32.SAC.deco.int.dat')
vel1e = datos1e[:,1]
t1e = datos1e[:,0]

datos1n = loadtxt('CX.HMBCX..HHN.D.2011.205.01.53.27.SAC.deco.int.dat')
vel1n = datos1n[:,1]
t1n = datos1n[:,0]

fig = plt.figure()
ax = fig.gca()
fig.set_size_inches(20,4)
plot(t1e, vel1e)
ax.set_xticks(np.arange(68,70,.1))
xlim([68,70])
#ax.set_xticks(np.arange(0,186,5))
#xlim([0,185])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ x$', fontsize=20)
title(r'$Sismograma \ E-W$', fontsize=20)

# %%
fig2 = plt.figure()
ax2 = fig2.gca()
fig2.set_size_inches(20,4)
plot(t1n, vel1n)
ax2.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid() 
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ y$', fontsize=20)
title(r'$Sismograma \ N-S$', fontsize=20)

# %%
e1 = []
n1 = []

for i in range(len(t1e)):
    if t1e[i]>=61.2 and t1e[i]<=61.28:
        e1.append(vel1e[i])
for j in range(len(t1n)):
    if t1n[j]>=67.2 and t1n[j]<=67.28:
        n1.append(vel1n[j]) 

plot(e1, n1)        
xlabel(r'$Velocidad \ en \ x \ (E)$', fontsize=15)
ylabel(r'$Velocidad \ en \ y \ (N)$', fontsize=15)
savefig('Mov_particulas1\HMBCX.pdf')

# %% [markdown]
# ## Hipocentro evento 1

# %%
tp = 61.2
ts = 68.6
#Distancia hipocentral --> hipotenusa del triangulo
dh = 8*(ts-tp)
#Distancia horizontal de la estación al centro del epicentro. Calculada con la regla de Google earth
de = 35 #km
#Usando pitagoras:
hi = sqrt(pow(dh,2)-pow(de,2))
print hi
# Out:
# 47.7455757113

# %% [markdown]
# El hipocentro se encuentra alrededor de 48 km del epicentro

# %% [markdown]
# Estación: CX.PB01

# %%
datos2e = loadtxt('CX.PB01..HHE.D.2011.205.01.53.42.SAC.deco.int.dat')
vel2e = datos2e[:,1]
t2e = datos2e[:,0]

datos2n = loadtxt('CX.PB01..HHN.D.2011.205.01.53.40.SAC.deco.int.dat')
vel2n = datos2n[:,1]
t2n = datos2n[:,0]

fig = plt.figure()
ax = fig.gca()
fig.set_size_inches(20,4)
plot(t2e, vel2e)
ax.set_xticks(np.arange(0,186,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ x$', fontsize=20)
title(r'$Sismograma \ E-W$', fontsize=20)

# %%
fig2 = plt.figure()
ax2 = fig2.gca()
fig2.set_size_inches(20,4)
plot(t2n, vel2n)
ax2.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid() 
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ y$', fontsize=20)
title(r'$Sismograma \ N-S$', fontsize=20)

# %%
e2 = []
n2 = []

for a in range(len(t2e)):
    if t2e[a]>=63.85 and t2e[a]<=63.9:
        e2.append(vel2e[a])
for b in range(len(t2n)):
    if t2n[b]>=64.75 and t2n[b]<=64.8:
        n2.append(vel2n[b])
        
fig5 = plt.figure()  
fig5.set_size_inches(10,6)
plot(e2, n2)  
xlabel(r'$Velocidad \ en \ x \ (E)$', fontsize=15)
ylabel(r'$Velocidad \ en \ y \ (N)$', fontsize=15)
savefig('Mov_particulas1\PB01.pdf')

# %%
datos3e = loadtxt('CX.PB08..HHE.D.2011.205.01.53.43.SAC.deco.int.dat')
vel3e = datos3e[:,1]
t3e = datos3e[:,0]

datos3n = loadtxt('CX.PB08..HHN.D.2011.205.01.53.38.SAC.deco.int.dat')
vel3n = datos3n[:,1]
t3n = datos3n[:,0]

fig4 = plt.figure()
ax4 = fig4.gca()
fig4.set_size_inches(20,4)
plot(t3e, vel3e)
ax4.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ x$', fontsize=20)
title(r'$Sismograma \ E-W$', fontsize=20)

# %%
fig6 = plt.figure()
ax6 = fig6.gca()
fig6.set_size_inches(20,4)
plot(t3n, vel3n)
ax6.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ y$', fontsize=20)
title(r'$Sismograma \ N-S$', fontsize=20)

# %%
e3 = []
n3 = []

for c in range(len(t3e)):
    if t3e[c]>=62.95 and t2e[c]<=63:
        e3.append(vel3e[c])
for d in range(len(t3n)):
    if t3n[d]>=67.95 and t3n[d]<=68:
        n3.append(vel3n[d])

figf = plt.figure()  
figf.set_size_inches(8,6)        
plot(e3, n3)   
xlabel(r'$Velocidad \ en \ x \ (E)$', fontsize=15)
ylabel(r'$Velocidad \ en \ y \ (N)$', fontsize=15)
savefig('Mov_particulas1\PB08.pdf')

# %%
datos4e = loadtxt('CX.PSGCX..HHE.D.2011.205.01.53.32.SAC.deco.int.dat')
vel4e = datos4e[:,1]
t4e = datos4e[:,0]

datos4n = loadtxt('CX.PSGCX..HHN.D.2011.205.01.53.28.SAC.deco.int.dat')
vel4n = datos4n[:,1]
t4n = datos4n[:,0]

fig9 = plt.figure()
ax9 = fig9.gca()
fig9.set_size_inches(20,4)
plot(t4e, vel4e)
ax9.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ x$', fontsize=20)
title(r'$Sismograma \ E-W$', fontsize=20)

# %%
figa = plt.figure()
axa = figa.gca()
figa.set_size_inches(20,4)
plot(t4n, vel4n)
xlim([0,190])
axa.set_xticks(np.arange(0,190,5))
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ y$', fontsize=20)
title(r'$Sismograma \ N-S$', fontsize=20)

# %%
e4 = []
n4 = []

for e in range(len(t4e)):
    if t4e[e]>=62.65 and t4e[e]<=62.8:
        e4.append(vel4e[e])
for f in range(len(t4n)):
    if t4n[f]>=67 and t4n[f]<=67.15:
        n4.append(vel4n[f])
        
plot(e4, n4)   
xlabel(r'$Velocidad \ en \ x \ (E)$', fontsize=15)
ylabel(r'$Velocidad \ en \ y \ (N)$', fontsize=15)
print (len(e4))
savefig('Mov_particulas1\PSGCX.pdf')
# Out:
# 16

# %%
datos5e = loadtxt('IQ.CERR..HHE.D.2011.205.01.53.38.SAC.deco.int.dat')
vel5e = datos5e[:,1]
t5e = datos5e[:,0]

datos5n = loadtxt('IQ.CERR..HHN.D.2011.205.01.53.36.SAC.deco.int.dat')
vel5n = datos5n[:,1]
t5n = datos5n[:,0]

figd = plt.figure()
axd = figd.gca()
figd.set_size_inches(20,4)
plot(t5e, vel5e)
axd.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ x$', fontsize=20)
title(r'$Sismograma \ E-W$', fontsize=20)

# %%
fige = plt.figure()
axe = fige.gca()
fige.set_size_inches(20,4)
plot(t5n, vel5n)
axe.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ y$', fontsize=20)
title(r'$Sismograma \ N-S$', fontsize=20)

# %%
e5 = []
n5 = []

for g in range(len(t5e)):
    if t5e[g]>=61.74 and t5e[g]<=61.78:
        e5.append(vel5e[g])
for h in range(len(t5n)):
    if t5n[h]>=63.76 and t5n[h]<=63.8:
        n5.append(vel5n[h])
        
figg = plt.figure()  
figg.set_size_inches(10,6)
plot(e5, n5)   
xlabel(r'$Velocidad \ en \ x \ (E)$', fontsize=15)
ylabel(r'$Velocidad \ en \ y \ (N)$', fontsize=15)
savefig('Mov_particulas1\CERR.pdf')

# %%
datos6e = loadtxt('IQ.HUAR..HHE.D.2011.205.01.53.34.SAC.deco.int.dat')
v6e = datos6e[:,1]
t6e = datos6e[:,0]

datos6n = loadtxt('IQ.HUAR..HHN.D.2011.205.01.53.35.SAC.deco.int.dat')
v6n = datos6n[:,1]
t6n = datos6n[:,0]

figh = plt.figure()
axh = figh.gca()
figh.set_size_inches(20,4)
plot(t6e, v6e)
axh.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ x$', fontsize=20)
title(r'$Sismograma \ E-W$', fontsize=20)

# %%
figi = plt.figure()
axi = figi.gca()
figi.set_size_inches(20,4)
plot(t6n, v6n)
axi.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ y$', fontsize=20)
title(r'$Sismograma \ N-S$', fontsize=20)

# %%
e6 = []
n6 = []

for k in range(len(t6e)):
    if t6e[k]>=63.1 and t6e[k]<=63.16:
        e6.append(v6e[k])
for l in range(len(t6n)):
    if t6n[l]>=62.2 and t6n[l]<=62.26:
        n6.append(v6n[l])
        
figh = plt.figure()  
figh.set_size_inches(10,6)
plot(e6, n6)   
xlabel(r'$Velocidad \ en \ x \ (E)$', fontsize=15)
ylabel(r'$Velocidad \ en \ y \ (N)$', fontsize=15)
savefig('Mov_particulas1\HUAR.pdf')

# %%
datos7e = loadtxt('IQ.MAM1..HHE.D.2011.205.01.53.40.SAC.deco.int.dat')
v7e = datos7e[:,1]
t7e = datos7e[:,0]

datos7n = loadtxt('IQ.MAM1..HHN.D.2011.205.01.53.40.SAC.deco.int.dat')
v7n = datos7n[:,1]
t7n = datos7n[:,0]

figk = plt.figure()
axk = figk.gca()
figk.set_size_inches(20,4)
plot(t7e, v7e)
axk.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ x$', fontsize=20)
title(r'$Sismograma \ E-W$', fontsize=20)

# %%
figl = plt.figure()
axl = figl.gca()
figl.set_size_inches(20,4)
plot(t7n, v7n)
axl.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ y$', fontsize=20)
title(r'$Sismograma \ N-S$', fontsize=20)

# %%
e7 = []
n7 = []

for n in range(len(t7e)):
    if t7e[n]>=61.56 and t7e[n]<=61.625:
        e7.append(v7e[n])
for o in range(len(t7n)):
    if t7n[o]>=60.95 and t7n[o]<=61.015:
        n7.append(v7n[o])
        
fign = plt.figure()  
fign.set_size_inches(10,6)
plot(e7, n7)   
xlabel(r'$Velocidad \ en \ x \ (E)$', fontsize=15)
ylabel(r'$Velocidad \ en \ y \ (N)$', fontsize=15)
savefig('Mov_particulas1\MAM1.pdf')

# %%
datos8e = loadtxt('IQ.PATA..HHE.D.2011.205.01.53.29.SAC.deco.int.dat')
v8e = datos8e[:,1]
t8e = datos8e[:,0]

datos8n = loadtxt('IQ.PATA..HHN.D.2011.205.01.53.32.SAC.deco.int.dat')
v8n = datos8n[:,1]
t8n = datos8n[:,0]

figo = plt.figure()
axo = figo.gca()
figo.set_size_inches(20,4)
plot(t8e, v8e)
axo.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ x$', fontsize=20)
title(r'$Sismograma \ E-W$', fontsize=20)

# %%
figp = plt.figure()
axp = figp.gca()
figp.set_size_inches(20,4)
plot(t8n, v8n)
axp.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ y$', fontsize=20)
title(r'$Sismograma \ N-S$', fontsize=20)

# %%
e8 = []
n8 = []

for p in range(len(t8e)):
    if t8e[p]>=66 and t8e[p]<=66.1:
        e8.append(v8e[p])
for q in range(len(t8n)):
    if t8n[q]>=63.6 and t8n[q]<=63.7:
        n8.append(v8n[q])
        
figs = plt.figure()  
figs.set_size_inches(10,6)
plot(e8, n8)   
xlabel(r'$Velocidad \ en \ x \ (E)$', fontsize=15)
ylabel(r'$Velocidad \ en \ y \ (N)$', fontsize=15)
savefig('Mov_particulas1\PATA.pdf')

# %%
datos9e = loadtxt('IQ.PICL..HHE.D.2011.205.01.53.42.SAC.deco.int.dat')
v9e = datos9e[:,1]
t9e = datos9e[:,0]

datos9n = loadtxt('IQ.PICL..HHN.D.2011.205.01.53.42.SAC.deco.int.dat')
v9n = datos9n[:,1]
t9n = datos9n[:,0]

figr = plt.figure()
axr = figr.gca()
figr.set_size_inches(20,4)
plot(t9e, v9e)
axr.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ x$', fontsize=20)
title(r'$Sismograma \ E-W$', fontsize=20)

# %%
figs = plt.figure()
axs = figs.gca()
figs.set_size_inches(20,4)
plot(t9n, v9n)
axs.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ y$', fontsize=20)
title(r'$Sismograma \ N-S$', fontsize=20)

# %%
e9 = []
n9 = []

for r in range(len(t9e)):
    if t9e[r]>=63.34 and t9e[r]<=63.4:
        e9.append(v9e[r])
for s in range(len(t9n)):
    if t9n[s]>=63.24 and t9n[s]<=63.3:
        n9.append(v9n[s])
        
figt = plt.figure()  
figt.set_size_inches(10,6)
plot(e9, n9)   
xlabel(r'$Velocidad \ en \ x \ (E)$', fontsize=15)
ylabel(r'$Velocidad \ en \ y \ (N)$', fontsize=15)
savefig('Mov_particulas1\PICL.pdf')

# %%
datosae = loadtxt('IQ.PINT..HHE.D.2011.205.01.53.43.SAC.deco.int.dat')
vae = datosae[:,1]
tae = datosae[:,0]

datosan = loadtxt('IQ.PINT..HHN.D.2011.205.01.53.43.SAC.deco.int.dat')
van = datosan[:,1]
tan = datosan[:,0]

fia = plt.figure()
aa = fia.gca()
fia.set_size_inches(20,4)
plot(tae, vae)
aa.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ x$', fontsize=20)
title(r'$Sismograma \ E-W$', fontsize=20)

# %%
fib = plt.figure()
ab = fib.gca()
fib.set_size_inches(20,4)
plot(tan, van)
ab.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ y$', fontsize=20)
title(r'$Sismograma \ N-S$', fontsize=20)

# %%
ea = []
na = []

for t in range(len(tae)):
    if tae[t]>=70.5 and tae[t]<=70.55:
        ea.append(vae[t])
for u in range(len(tan)):
    if tan[u]>=63.2 and tan[u]<=63.25:
        na.append(van[u])
        
figt = plt.figure()  
figt.set_size_inches(10,6)
plot(ea, na)   
xlabel(r'$Velocidad \ en \ x \ (E)$', fontsize=15)
ylabel(r'$Velocidad \ en \ y \ (N)$', fontsize=15)
savefig('Mov_particulas1\PINT.pdf')

# %%
datosbe = loadtxt('IQ.SOG1..HHE.D.2011.205.01.53.37.SAC.deco.int.dat')
vbe = datosbe[:,1]
tbe = datosbe[:,0]

datosbn = loadtxt('IQ.SOG1..HHN.D.2011.205.01.53.35.SAC.deco.int.dat')
vbn = datosbn[:,1]
tbn = datosbn[:,0]

fib = plt.figure()
ab = fib.gca()
fib.set_size_inches(20,4)
plot(tbe, vbe)
ab.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ x$', fontsize=20)
title(r'$Sismograma \ E-W$', fontsize=20)

# %%
fic = plt.figure()
ac = fic.gca()
fic.set_size_inches(20,4)
plot(tbn, vbn)
ac.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ y$', fontsize=20)
title(r'$Sismograma \ N-S$', fontsize=20)

# %%
eb = []
nb = []

for v in range(len(tbe)):
    if tbe[v]>=63.73 and tbe[v]<=63.78:
        eb.append(vbe[v])
for w in range(len(tbn)):
    if tbn[w]>=65.25 and tbn[w]<=65.3:
        nb.append(vbn[w])
        
figt = plt.figure()  
figt.set_size_inches(10,6)
plot(eb, nb)   
xlabel(r'$Velocidad \ en \ x \ (E)$', fontsize=15)
ylabel(r'$Velocidad \ en \ y \ (N)$', fontsize=15)
savefig('Mov_particulas1\SOG1.pdf')

# %%
datosce = loadtxt('IQ.SOG2..HHE.D.2011.205.01.53.41.SAC.deco.int.dat')
vce = datosce[:,1]
tce = datosce[:,0]

datoscn = loadtxt('IQ.SOG2..HHN.D.2011.205.01.53.40.SAC.deco.int.dat')
vcn = datoscn[:,1]
tcn = datoscn[:,0]

fid = plt.figure()
ad = fid.gca()
fid.set_size_inches(20,4)
plot(tce, vce)
ad.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ x$', fontsize=20)
title(r'$Sismograma \ E-W$', fontsize=20)

# %%
fie = plt.figure()
ae = fie.gca()
fie.set_size_inches(20,4)
plot(tcn, vcn)
ae.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ y$', fontsize=20)
title(r'$Sismograma \ N-S$', fontsize=20)

# %%
ec= []
nc = []

for x in range(len(tce)):
    if tce[x]>=64.9 and tce[x]<=64.96:
        ec.append(vce[x])
for y in range(len(tcn)):
    if tcn[y]>=64.7 and tcn[y]<=64.76:
        nc.append(vcn[y])
        
figt = plt.figure()  
figt.set_size_inches(10,6)
plot(ec, nc)   
xlabel(r'$Velocidad \ en \ x \ (E)$', fontsize=15)
ylabel(r'$Velocidad \ en \ y \ (N)$', fontsize=15)
savefig('Mov_particulas1\SOG2.pdf')

# %%
datosde = loadtxt('IQ.UNAP..HHE.D.2011.205.01.53.28.SAC.deco.int.dat')
vde = datosde[:,1]
tde = datosde[:,0]

datosdn = loadtxt('IQ.UNAP..HHN.D.2011.205.01.53.28.SAC.deco.int.dat')
vdn = datosdn[:,1]
tdn = datosdn[:,0]

fie = plt.figure()
ae = fie.gca()
fie.set_size_inches(20,4)
plot(tde, vde)
ae.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ x$', fontsize=20)
title(r'$Sismograma \ E-W$', fontsize=20)

# %%
fif = plt.figure()
af = fif.gca()
fif.set_size_inches(20,4)
plot(tdn, vdn)
af.set_xticks(np.arange(0,190,5))
xlim([0,190])
grid()
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Velocidad \ en \ y$', fontsize=20)
title(r'$Sismograma \ N-S$', fontsize=20)

# %%
ed= []
nd = []

for z in range(len(tde)):
    if tde[z]>=62.1 and tde[z]<=62.15:
        ed.append(vde[z])
for ar in range(len(tdn)):
    if tdn[ar]>=69.8 and tdn[ar]<=69.85:
        nd.append(vdn[ar])
        
figt = plt.figure()  
figt.set_size_inches(10,6)
plot(ed, nd)   
xlabel(r'$Velocidad \ en \ x \ (E)$', fontsize=15)
ylabel(r'$Velocidad \ en \ y \ (N)$', fontsize=15)
savefig('Mov_particulas1\UNAP.pdf')
