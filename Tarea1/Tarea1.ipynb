# %% [markdown]
# ## Tarea 1 Sismología

# %% [markdown]
# ### Universidad de Chile

# %% [markdown]
# ##### Por: Aura Cuervo

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
import math
from IPython.display import Image
from itertools import groupby
from collections import OrderedDict
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['size']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ### Pregunta 1

# %%
sismicidad = loadtxt('sismicidad20.txt')
lat = sismicidad[:,3]
lon = sismicidad[:,4]

fosa = loadtxt('fosa.dat')
flat = fosa[:,0]
flon = fosa[:,1]

chile = loadtxt('Chile.dat')
clat = chile[:,1]
clon = chile[:,0]

fig, ax = plt.subplots()

fig.set_size_inches(10,15)
ax.plot(clon,clat,'g')
ax.lines[-1].set_linewidth(2)
ax.plot(flon,flat,'b')
ax.lines[-1].set_linewidth(2)
ax.scatter(lon,lat,color=('red'),s=10,alpha=1)

xlim([-78,-65])
ylim([-56,-14])

xlabel(r'$Longitud$', fontsize=20)
ylabel(r'$Latitud$', fontsize=20)
title(r'$Sismicidad \ en \ Iquique$', fontsize=30)

# %%
prof_pos = sismicidad[:,5]
n = -1
prof_neg = multiply(prof_pos,n)

fig = plt.figure()
ax = fig.gca()

fig.set_size_inches(13,8)
ax.set_xticks(np.arange(-72,-68.9,0.25))
ax.set_yticks(np.arange(-140,20,5))
ax.scatter(lon,prof_neg,color=('red'),s=10,alpha=0.5)
grid()

xlim([-72,-68.9])
xlabel(r'$Longitud$', fontsize=20)
ylabel(r'$Profundidad \ (km)$', fontsize=20)
savefig('corte_sismicidad.png')
plt.clf()

#Fuente: http://nbviewer.ipython.org/github/olgabot/ipython/blob/1.x/examples/notebooks/Part%205%20-%20Rich%20Display%20System.ipynb
i = Image(filename='corte_sism.png')
i

# %% [markdown]
# Es posible agrupar los eventos del corte anterior en las 4 fuentes sismogénicas existentes en las zonas de subducción: outer rise, interplaca, intraplaca oceánica y cortical.

# %% [markdown]
# #### Outer rise

# %% [markdown]
# Producida por la extensión y comprensión de la placa oceánica previa a la subducción. Se encuentran aproximadamente a 150 km de la costa, por lo cual generan daños moderados. En la imagen anterior, corresponden al grupo a.

# %% [markdown]
# #### Interplaca tipo "thrust"

# %% [markdown]
# Se producen en el contacto entre la placa oceánica y continental, se ubican entre la fosa y 50-60 km de profundidad. En la imagen anterior, se encuentran en el grupo b.

# %% [markdown]
# #### Intraplaca de profundidad intermedia

# %% [markdown]
# Son los eventos que ocurren en la placa oceánica entre 50 y 200 km de profundidad. Pertenecen al grupo c de la imagen.

# %% [markdown]
# #### Cortical

# %% [markdown]
# Es la sismicidad producida en la placa continental que no supera los 30 km de profundidad. Se ubica principalmente en las coordilleras y sus alrededores. Corresponden al grupo d de la imagen.

# %% [markdown]
# Fuente: http://www.scielo.cl/scielo.php?script=sci_arttext&pid=S0718-71062010000200011

# %% [markdown]
# De esta manera, se espera que en Argentina y Bolivia los tipos de sismicidad sean: intraplaca de profundidad intermedia y corticales, porque se encuentra más al Este del margen convergente. De acuerdo a las profundidades del mapa de sismicidad de Argentina, en esta zona también ocurren sismos de interplaca tipo thrust. Mientras que en Perú se espera que los sismos correspondan a los mismos tipos de sismicidad que Chile, es decir, los 4 existentes para una zona de subducción por su ubicación geográfica.

# %% [markdown]
# Fuente: http://www.inpres.gov.ar/seismology/sismicidad.html

# %% [markdown]
# ### Pregunta 2

# %%
anho = sismicidad[:,0]
mes = sismicidad[:,1]
dias = sismicidad[:,2]
magnitud = sismicidad[:,6]
size = len(mes)
dias_enero = []
mag_enero = []

#Seleccionando los días con sismos de enero 2014 - Cluster 1
for i in range(size):
    if (anho[i] == 2014 and mes[i] == 1):
        #Seleccionando los sismos que ocurrieron entre las latitudes -20° y -21° y las longitudes -70.4° y 71°
        if (lat[i]>=-21 and lat[i]<=-20 and lon[i]>=-71 and lon[i]<=-70.4):
            dias_enero.append(dias[i])
            mag_enero.append(magnitud[i])

#Contando el número de sismos por día
num_sismos = [len(list(group)) for key, group in groupby(dias_enero)]
dias_en = list(OrderedDict.fromkeys(dias_enero))

plt.figure(figsize=(18, 6))
plt.subplot(121)
plt.scatter(dias_en, num_sismos, color = "blue", s= 80, alpha = 0.6 )
plt.xlabel(r'$dias$', fontsize=15)
plt.ylabel(r'$Numero \ de \ sismos$', fontsize=15)
plt.text(25, 10, "$\mathrm{Cluster \ enero \ 2014}$", fontsize=30, rotation='horizontal')
plt.subplot(122)
plt.scatter(dias_enero, mag_enero, color = "green", s= 80, alpha = 0.6 )
plt.xlabel(r'$dias$', fontsize=15)
plt.ylabel(r'$Magnitud$', fontsize=15)

# %%
dias4 = []
mag4 = []
dias5 = []
mag5 = []
dias6 = []
mag6 = []
dias7 = []
mag7 = []
dias8 = []
mag8 = []
dias9 = []
mag9 = []
dias10 = []
mag10 = []
dias11 = []
mag11 = []
dias12 = []
mag12 = []
dias1 = []
mag1 = []
dias2 = []
mag2 = []
dias3 = []
mag3 = []

#A continuación se separan los datos por meses y se cuenta el número de sismos por día
for i in range(size):
    if (mes[i] == 4):
        #Seleccionando los sismos que ocurrieron entre las latitudes -20° y -21° y las longitudes -70.4° y 71°
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias4.append(dias[i])
            mag4.append(magnitud[i])
    elif (mes[i] == 5):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias5.append(dias[i])
            mag5.append(magnitud[i])
    elif (mes[i] == 6):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias6.append(dias[i])
            mag6.append(magnitud[i])   
    elif (mes[i] == 7):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias7.append(dias[i])
            mag7.append(magnitud[i])     
    elif (mes[i] == 8):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias8.append(dias[i])
            mag8.append(magnitud[i])   
    elif (mes[i] == 9):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias9.append(dias[i])
            mag9.append(magnitud[i])        
    elif (mes[i] == 10):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias10.append(dias[i])
            mag10.append(magnitud[i])        
    elif (mes[i] == 11):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias11.append(dias[i])
            mag11.append(magnitud[i])
    elif (mes[i] == 12):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias12.append(dias[i])
            mag12.append(magnitud[i])   
    elif (anho[i] == 2015 and mes[i] == 1):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias1.append(dias[i])
            mag1.append(magnitud[i])
    elif (anho[i] == 2015 and mes[i] == 2):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias2.append(dias[i])
            mag2.append(magnitud[i])
    elif (anho[i] == 2015 and mes[i] == 3):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias3.append(dias[i])
            mag3.append(magnitud[i])
num4 = []            
num4 = [len(list(group)) for key, group in groupby(dias4)]
ndia4 = list(OrderedDict.fromkeys(dias4))
num5 = [len(list(group)) for key, group in groupby(dias5)]
ndia5 = list(OrderedDict.fromkeys(dias5))
num6 = [len(list(group)) for key, group in groupby(dias6)]
ndia6 = list(OrderedDict.fromkeys(dias6))
num7 = [len(list(group)) for key, group in groupby(dias7)]
ndia7 = list(OrderedDict.fromkeys(dias7))
num8 = [len(list(group)) for key, group in groupby(dias8)]
ndia8 = list(OrderedDict.fromkeys(dias8))
num9 = [len(list(group)) for key, group in groupby(dias9)]
ndia9 = list(OrderedDict.fromkeys(dias9))
num10 = [len(list(group)) for key, group in groupby(dias10)]
ndia10 = list(OrderedDict.fromkeys(dias10))
num11 = [len(list(group)) for key, group in groupby(dias11)]
ndia11 = list(OrderedDict.fromkeys(dias11))
num12 = [len(list(group)) for key, group in groupby(dias12)]
ndia12 = list(OrderedDict.fromkeys(dias12))
num1 = [len(list(group)) for key, group in groupby(dias1)]
ndia1 = list(OrderedDict.fromkeys(dias1))
num2 = [len(list(group)) for key, group in groupby(dias2)]
ndia2 = list(OrderedDict.fromkeys(dias2))
num3 = [len(list(group)) for key, group in groupby(dias3)]
ndia3 = list(OrderedDict.fromkeys(dias3))

# %%
#Completando las listas para poder graficar
for f in range(0,1):
    ndia9.append(0)
for k in range(0,1):
    ndia11.append(0)
    
for j in range(0,30):
    if(ndia4[j] != j+1):
        ndia4.insert(j,j+1)
        num4.insert(j,0)
    if(ndia6[j] != j+1):
        ndia6.insert(j,j+1)
        num6.insert(j,0)
    if(ndia9[j] != j+1):
        ndia9.insert(j,j+1)
        num9.insert(j,0)
    if(ndia11[j] != j+1):
        ndia11.insert(j,j+1)
        num11.insert(j,0)

for g in range(0,1):
    ndia8.append(0)
for h in range(0,1):
    ndia10.append(0)
for l in range(0,1):
    ndia12.append(0)
for m in range(0,1):
    ndia1.append(0)
for o in range(0,1):
    ndia3.append(0)
    
for h in range(0,31):
    if(ndia5[h] != h+1):
        ndia5.insert(h,h+1)
        num5.insert(h,0)
    if(ndia7[h] != h+1):
        ndia7.insert(h,h+1)
        num7.insert(h,0)
    if(ndia8[h] != h+1):
        ndia8.insert(h,h+1)
        num8.insert(h,0)
    if(ndia12[h] != h+1):
        ndia12.insert(h,h+1)
        num12.insert(h,0)
    if(ndia10[h] != h+1):
        ndia10.insert(h,h+1)
        num10.insert(h,0)
    if(ndia1[h] != h+1):
        ndia1.insert(h,h+1)
        num1.insert(h,0)
    if(ndia3[h] != h+1):
        ndia3.insert(h,h+1)
        num3.insert(h,0)

for n in range(0,1):
    ndia2.append(0)
    
for p in range(0,28):
    if(ndia2[p] != p+1):
        ndia2.insert(p,p+1)
        num2.insert(p,0)

# %%
anhoc = []
for q in range(0,365):
    anhoc.append(q+1)
total_sismos = []
total_sismos = num4+num5+num6+num7+num8+num9+num10+num11+num12+num1+num2+num3

print len(anhoc), len(total_sismos)
plt.figure(figsize=(16, 6))
#plt.subplot(121)
plt.scatter(anhoc, total_sismos, color = "blue", s= 80, alpha = 0.6 )
plt.xlabel(r'$dias$', fontsize=15)
plt.ylabel(r'$Numero \ de \ sismos$', fontsize=15)
grid()
# Out:
# 365 365
