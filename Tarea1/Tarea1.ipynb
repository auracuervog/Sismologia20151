# %% [markdown]
# ## Tarea 1 Sismología

# %% [markdown]
# ### Universidad de Chile

# %% [markdown]
# ##### Por: Aura Cuervo

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
import math
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ### Pregunta 1

# %%
sismicidad = loadtxt('sismicidad20.txt')
lat = sismicidad[:,3]
lon = sismicidad[:,4]

fosa = loadtxt('fosa.dat')
flat = fosa[:,0]
flon = fosa[:,1]

chile = loadtxt('Chile.dat')
clat = chile[:,1]
clon = chile[:,0]

fig, ax = plt.subplots()

fig.set_size_inches(10,15)
ax.plot(clon,clat,'g')
ax.lines[-1].set_linewidth(2)
ax.plot(flon,flat,'b')
ax.lines[-1].set_linewidth(2)
ax.scatter(lon,lat,color=('red'),s=10,alpha=1)

xlim([-78,-65])
ylim([-56,-14])

xlabel(r'$Longitud$', fontsize=20)
ylabel(r'$Latitud$', fontsize=20)
title(r'$Sismicidad \ en \ Iquique$', fontsize=30)

# %%
prof_pos = sismicidad[:,5]
n = -1
prof_neg = multiply(prof_pos,n)

fig, ax = plt.subplots()

fig.set_size_inches(10,5)
ax.scatter(lon,prof_neg,color=('red'),s=10,alpha=0.5)
xlim([-72,-68.9])
xlabel(r'$Longitud$', fontsize=20)
ylabel(r'$Profundidad \ (km)$', fontsize=20)

#Agrupando los tipos de sismicidad
