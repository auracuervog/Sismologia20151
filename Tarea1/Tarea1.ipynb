# %% [markdown]
# ## Tarea 1 Sismología

# %% [markdown]
# ### Universidad de Chile

# %% [markdown]
# ##### Por: Aura Cuervo

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
import math
from IPython.display import Image
from itertools import groupby
from collections import OrderedDict
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f', 'qr', 'size']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ### Pregunta 1

# %%
sismicidad = loadtxt('sismicidad20.txt')
lat = sismicidad[:,3]
lon = sismicidad[:,4]

fosa = loadtxt('fosa.dat')
flat = fosa[:,0]
flon = fosa[:,1]

chile = loadtxt('Chile.dat')
clat = chile[:,1]
clon = chile[:,0]

fig, ax = plt.subplots()

fig.set_size_inches(10,15)
ax.plot(clon,clat,'g')
ax.lines[-1].set_linewidth(2)
ax.plot(flon,flat,'b')
ax.lines[-1].set_linewidth(2)
ax.scatter(lon,lat,color=('red'),s=10,alpha=1)

xlim([-78,-65])
ylim([-56,-14])

xlabel(r'$Longitud$', fontsize=20)
ylabel(r'$Latitud$', fontsize=20)
title(r'$Sismicidad \ en \ Iquique$', fontsize=30)

# %%
prof_pos = sismicidad[:,5]
n = -1
prof_neg = multiply(prof_pos,n)

fig = plt.figure()
ax = fig.gca()

fig.set_size_inches(13,8)
ax.set_xticks(np.arange(-72,-68.9,0.25))
ax.set_yticks(np.arange(-140,20,5))
ax.scatter(lon,prof_neg,color=('red'),s=10,alpha=0.5)
grid()

xlim([-72,-68.9])
xlabel(r'$Longitud$', fontsize=20)
ylabel(r'$Profundidad \ (km)$', fontsize=20)
savefig('corte_sismicidad.png')
plt.clf()

#Fuente: http://nbviewer.ipython.org/github/olgabot/ipython/blob/1.x/examples/notebooks/Part%205%20-%20Rich%20Display%20System.ipynb
i = Image(filename='corte_sism.png')
i

# %% [markdown]
# Es posible agrupar los eventos del corte anterior en las 4 fuentes sismogénicas existentes en las zonas de subducción: outer rise, interplaca, intraplaca oceánica y cortical.

# %% [markdown]
# #### Outer rise

# %% [markdown]
# Producida por la extensión y comprensión de la placa oceánica previa a la subducción. Se encuentran aproximadamente a 150 km de la costa, por lo cual generan daños moderados. En la imagen anterior, corresponden al grupo a.

# %% [markdown]
# #### Interplaca tipo "thrust"

# %% [markdown]
# Se producen en el contacto entre la placa oceánica y continental, se ubican entre la fosa y 50-60 km de profundidad. En la imagen anterior, se encuentran en el grupo b.

# %% [markdown]
# #### Intraplaca de profundidad intermedia

# %% [markdown]
# Son los eventos que ocurren en la placa oceánica entre 50 y 200 km de profundidad. Pertenecen al grupo c de la imagen.

# %% [markdown]
# #### Cortical

# %% [markdown]
# Es la sismicidad producida en la placa continental que no supera los 30 km de profundidad. Se ubica principalmente en las coordilleras y sus alrededores. Corresponden al grupo d de la imagen.

# %% [markdown]
# Fuente: http://www.scielo.cl/scielo.php?script=sci_arttext&pid=S0718-71062010000200011

# %% [markdown]
# De esta manera, se espera que en Argentina y Bolivia los tipos de sismicidad sean: intraplaca de profundidad intermedia y corticales, porque se encuentra más al Este del margen convergente. De acuerdo a las profundidades del mapa de sismicidad de Argentina, en esta zona también ocurren sismos de interplaca tipo thrust. Mientras que en Perú se espera que los sismos correspondan a los mismos tipos de sismicidad que Chile, es decir, los 4 existentes para una zona de subducción por su ubicación geográfica.

# %% [markdown]
# Fuente: http://www.inpres.gov.ar/seismology/sismicidad.html

# %% [markdown]
# ### Pregunta 2

# %%
anho = sismicidad[:,0]
mes = sismicidad[:,1]
dias = sismicidad[:,2]
magnitud = sismicidad[:,6]
size = len(mes)
dias_enero = []
mag_enero = []

#Seleccionando los días con sismos de enero 2014 - Cluster 1
for i in range(size):
    if (anho[i] == 2014 and mes[i] == 1):
        #Seleccionando los sismos que ocurrieron entre las latitudes -20° y -21° y las longitudes -70.4° y 71°
        if (lat[i]>=-21 and lat[i]<=-20 and lon[i]>=-71 and lon[i]<=-70.4):
            dias_enero.append(dias[i])
            mag_enero.append(magnitud[i])

#Contando el número de sismos por día
num_sismos = [len(list(group)) for key, group in groupby(dias_enero)]
dias_en = list(OrderedDict.fromkeys(dias_enero))

plt.figure(figsize=(18, 6))
plt.subplot(121)
plt.scatter(dias_en, num_sismos, color = "blue", s= 80, alpha = 0.6 )
plt.xlabel(r'$dias$', fontsize=15)
plt.ylabel(r'$Numero \ de \ sismos$', fontsize=15)
plt.text(25, 10, "$\mathrm{Cluster \ enero \ 2014}$", fontsize=30, rotation='horizontal')
plt.subplot(122)
plt.scatter(dias_enero, mag_enero, color = "green", s= 80, alpha = 0.6 )
plt.xlabel(r'$dias$', fontsize=15)
plt.ylabel(r'$Magnitud$', fontsize=15)

# %%
dias4 = []; mag4 = []; dias5 = []; mag5 = []; dias6 = []; mag6 = []; dias7 = []; mag7 = []; dias8 = []; mag8 = []; dias9 = []; mag9 = []; dias10 = []
mag10 = []; dias11 = []; mag11 = []; dias12 = []; mag12 = []; dias1 = []; mag1 = []; dias2 = []; mag2 = []; dias3 = []; mag3 = []

#A continuación se separan los datos por meses y se cuenta el número de sismos por día
for i in range(size):
    if (mes[i] == 4):
        #Seleccionando los sismos que ocurrieron entre las latitudes -20° y -21° y las longitudes -70.4° y 71°
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias4.append(dias[i])
            mag4.append(magnitud[i])
    elif (mes[i] == 5):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias5.append(dias[i])
            mag5.append(magnitud[i])
    elif (mes[i] == 6):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias6.append(dias[i])
            mag6.append(magnitud[i])   
    elif (mes[i] == 7):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias7.append(dias[i])
            mag7.append(magnitud[i])     
    elif (mes[i] == 8):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias8.append(dias[i])
            mag8.append(magnitud[i])   
    elif (mes[i] == 9):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias9.append(dias[i])
            mag9.append(magnitud[i])        
    elif (mes[i] == 10):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias10.append(dias[i])
            mag10.append(magnitud[i])        
    elif (mes[i] == 11):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias11.append(dias[i])
            mag11.append(magnitud[i])
    elif (mes[i] == 12):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias12.append(dias[i])
            mag12.append(magnitud[i])   
    elif (anho[i] == 2015 and mes[i] == 1):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias1.append(dias[i])
            mag1.append(magnitud[i])
    elif (anho[i] == 2015 and mes[i] == 2):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias2.append(dias[i])
            mag2.append(magnitud[i])
    elif (anho[i] == 2015 and mes[i] == 3):
        if (lat[i]>=-20.5 and lat[i]<=-19 and lon[i]>=-71.2 and lon[i]<=-70.2):
            dias3.append(dias[i])
            mag3.append(magnitud[i])
num4 = []            
num4 = [len(list(group)) for key, group in groupby(dias4)]
ndia4 = list(OrderedDict.fromkeys(dias4))
num5 = [len(list(group)) for key, group in groupby(dias5)]
ndia5 = list(OrderedDict.fromkeys(dias5))
num6 = [len(list(group)) for key, group in groupby(dias6)]
ndia6 = list(OrderedDict.fromkeys(dias6))
num7 = [len(list(group)) for key, group in groupby(dias7)]
ndia7 = list(OrderedDict.fromkeys(dias7))
num8 = [len(list(group)) for key, group in groupby(dias8)]
ndia8 = list(OrderedDict.fromkeys(dias8))
num9 = [len(list(group)) for key, group in groupby(dias9)]
ndia9 = list(OrderedDict.fromkeys(dias9))
num10 = [len(list(group)) for key, group in groupby(dias10)]
ndia10 = list(OrderedDict.fromkeys(dias10))
num11 = [len(list(group)) for key, group in groupby(dias11)]
ndia11 = list(OrderedDict.fromkeys(dias11))
num12 = [len(list(group)) for key, group in groupby(dias12)]
ndia12 = list(OrderedDict.fromkeys(dias12))
num1 = [len(list(group)) for key, group in groupby(dias1)]
ndia1 = list(OrderedDict.fromkeys(dias1))
num2 = [len(list(group)) for key, group in groupby(dias2)]
ndia2 = list(OrderedDict.fromkeys(dias2))
num3 = [len(list(group)) for key, group in groupby(dias3)]
ndia3 = list(OrderedDict.fromkeys(dias3))

# %%
#Completando las listas para poder graficar
for f in range(0,1):
    ndia9.append(0)
for k in range(0,1):
    ndia11.append(0)
    
for j in range(0,30):
    if(ndia4[j] != j+1):
        ndia4.insert(j,j+1)
        num4.insert(j,0)
    if(ndia6[j] != j+1):
        ndia6.insert(j,j+1)
        num6.insert(j,0)
    if(ndia9[j] != j+1):
        ndia9.insert(j,j+1)
        num9.insert(j,0)
    if(ndia11[j] != j+1):
        ndia11.insert(j,j+1)
        num11.insert(j,0)

for g in range(0,1):
    ndia8.append(0)
for h in range(0,1):
    ndia10.append(0)
for l in range(0,1):
    ndia12.append(0)
for m in range(0,1):
    ndia1.append(0)
for o in range(0,1):
    ndia3.append(0)
    
for h in range(0,31):
    if(ndia5[h] != h+1):
        ndia5.insert(h,h+1)
        num5.insert(h,0)
    if(ndia7[h] != h+1):
        ndia7.insert(h,h+1)
        num7.insert(h,0)
    if(ndia8[h] != h+1):
        ndia8.insert(h,h+1)
        num8.insert(h,0)
    if(ndia12[h] != h+1):
        ndia12.insert(h,h+1)
        num12.insert(h,0)
    if(ndia10[h] != h+1):
        ndia10.insert(h,h+1)
        num10.insert(h,0)
    if(ndia1[h] != h+1):
        ndia1.insert(h,h+1)
        num1.insert(h,0)
    if(ndia3[h] != h+1):
        ndia3.insert(h,h+1)
        num3.insert(h,0)

for n in range(0,1):
    ndia2.append(0)
    
for p in range(0,28):
    if(ndia2[p] != p+1):
        ndia2.insert(p,p+1)
        num2.insert(p,0)

# %%
cont5 = 1.0
for u in range(0,2):
    dias5.append(0)
for v in range(0,len(dias5)):
    if(dias5[v]!=cont5):
        dias5.insert(v,cont5)
        mag5.insert(v,0)
        cont5+=1
    elif(dias5[v]==cont5 and dias5[v]!=dias5[v+1]):
        cont5+=1
for w in range(205,207):
        dias5.remove(0)

cont6 = 1.0
for x in range(0,3):
    dias6.append(0)
for y in range(0,len(dias6)):
    if(dias6[y]!=cont6):
        dias6.insert(y,cont6)
        mag6.insert(y,0)
        cont6+=1
    elif(dias6[y]==cont6 and dias6[y]!=dias6[y+1]):
        cont6+=1
for z in range(141,144):
        dias6.remove(0)        

cont7 = 1.0
for ab in range(0,6):
    dias7.append(0)
for bc in range(0,len(dias7)):
    if(dias7[bc]!=cont7):
        dias7.insert(bc,cont7)
        mag7.insert(bc,0)
        cont7+=1
    elif(dias7[bc]==cont7 and dias7[bc]!=dias7[bc+1]):
        cont7+=1
for cd in range(66,72):
        dias7.remove(0) 

cont8 = 1.0
for de in range(0,8):
    dias8.append(0)
for ef in range(0,len(dias8)):
    if(dias8[ef]!=cont8):
        dias8.insert(ef,cont8)
        mag8.insert(ef,0)
        cont8+=1
    elif(dias8[ef]==cont8 and dias8[ef]!=dias8[ef+1]):
        cont8+=1
for fg in range(51,59):
        dias8.remove(0) 

cont9 = 1.0
for gh in range(0,10):
    dias9.append(0)
for hi in range(0,len(dias9)):
    if(dias9[hi]!=cont9):
        dias9.insert(hi,cont9)
        mag9.insert(hi,0)
        cont9+=1
    elif(dias9[hi]==cont9 and dias9[hi]!=dias9[hi+1]):
        cont9+=1
for ij in range(40,50):
        dias9.remove(0) 
        
cont10 = 1.0
for jk in range(0,17):
    dias10.append(0)
for kl in range(0,len(dias10)):
    if(dias10[kl]!=cont10):
        dias10.insert(kl,cont10)
        mag10.insert(kl,0)
        cont10+=1
    elif(dias10[kl]==cont10 and dias10[kl]!=dias10[kl+1]):
        cont10+=1
for lm in range(43,60):
        dias10.remove(0)

cont11 = 1.0
for mn in range(0,14):
    dias11.append(0)
for nh in range(0,len(dias11)):
    if(dias11[nh]!=cont11):
        dias11.insert(nh,cont11)
        mag11.insert(nh,0)
        cont11+=1
    elif(dias11[nh]==cont11 and dias11[nh]!=dias11[nh+1]):
        cont11+=1
for ho in range(39,53):
        dias11.remove(0)
        
cont12 = 1.0
for op in range(0,17):
    dias12.append(0)
for pq in range(0,len(dias12)):
    if(dias12[pq]!=cont12):
        dias12.insert(pq,cont12)
        mag12.insert(pq,0)
        cont12+=1
    elif(dias12[pq]==cont12 and dias12[pq]!=dias12[pq+1]):
        cont12+=1
for qr in range(50,67):
        dias12.remove(0)
        
cont1 = 1.0
for rs in range(0,18):
    dias1.append(0)
for st in range(0,len(dias1)):
    if(dias1[st]!=cont1):
        dias1.insert(st,cont1)
        mag1.insert(st,0)
        cont1+=1
    elif(dias1[st]==cont1 and dias1[st]!=dias1[st+1]):
        cont1+=1
for uv in range(46,64):
        dias1.remove(0)
        
cont2 = 1.0
for az in range(0,15):
    dias2.append(0)
for zx in range(0,len(dias2)):
    if(dias2[zx]!=cont2):
        dias2.insert(zx,cont2)
        mag2.insert(zx,0)
        cont2+=1
    elif(dias2[zx]==cont2 and dias2[zx]!=dias2[zx+1]):
        cont2+=1
for xc in range(40,55):
        dias2.remove(0)
        
cont3 = 1.0
for o in range(0,(32-len(dias3))):
    dias3.append(0)
    
for r in range(0,len(dias3)):
    if(dias3[r]!=cont3):
        dias3.insert(r,cont3)
        mag3.insert(r,0)
        cont3+=1
    elif(dias3[r]==cont3 and dias3[r]!=dias3[r+1]):
        cont3+=1
for t in range(32,57):
        dias3.remove(0)
total_dias = []
total_dias = dias1+dias2+dias3+dias4+dias5+dias6+dias7+dias8+dias9+dias10+dias11+dias12

#Se guardan los datos de los días para modificarlos como números consecutivos en excel
f = open("days.txt", "w")
for ele in total_dias:
    f.write(str(ele)+'\n')
f.close()

# %%
anhoc = []
for q in range(0,365):
    anhoc.append(q+1)

fig = plt.figure()
ax = fig.gca()

fig.set_size_inches(16,6)
ax.set_xticks(np.arange(-10,370,20))
ax.set_yticks(np.arange(-10,150,10))
ax.scatter(anhoc, total_sismos, color = "blue", s= 80, alpha = 0.6 )
grid()

plt.xlabel(r'$dias$', fontsize=20)
plt.ylabel(r'$Numero \ de \ sismos$', fontsize=20)
plt.text(82.5, 165, "$\mathrm{Cluster \ abril \ 2014 \ a \ marzo \ 2015 }$", fontsize=30, rotation='horizontal')

# %%
total_sismos = []
total_sismos = num4+num5+num6+num7+num8+num9+num10+num11+num12+num1+num2+num3

total_mag = []
total_dias = []
total_mag = mag1+mag2+mag3+mag4+mag5+mag6+mag7+mag8+mag9+mag10+mag11+mag12

#Se guardan los consecutivos de los días en una lista
file = open('tot_days.txt','r')
for line in file:
    total_dias.append(line.strip())

fig = plt.figure()
ax = fig.gca()

fig.set_size_inches(16,6)
ax.set_xticks(np.arange(-10,370,20))
ax.set_yticks(np.arange(1,15,1))
ax.scatter(total_dias, total_mag, color = "green", s= 80, alpha = 0.6 )
grid()
ylim([1,9])
plt.ylabel(r'$Magnitud$', fontsize=20)  
plt.xlabel(r'$dias$', fontsize=20)
plt.text(82.5, 10, "$\mathrm{Cluster \ abril \ 2014 \ a \ marzo \ 2015 }$", fontsize=30, rotation='horizontal')

# %% [markdown]
# #### Pregunta 2.1

# %% [markdown]
# Es importante resaltar que los clusters de los gráficos anteriores corresponden a zonas de sismicidad interplaca tipo thrust.

# %% [markdown]
# Al observar el gráfico de número de sismos vs. días de enero del 2014 es claro como aumenta rápidamente la actividad sísmica de la zona hasta el evento principal, para después disminuir la frecuencia de eventos con el paso del tiempo. Esta tendencia es similar a la del segundo cluster, donde la cantidad de sismos disminuye rápidamente hasta estabilizarse después del sismo principal que ocurre en abril del 2014.

# %% [markdown]
#  Por otro lado, el comportamiento general de las gráficas de magnitud vs. días no sigue un patrón tan uniforme. Para el primer caso (abril 2014), se observa que la magnitud de los eventos disminuye en poco tiempo. En la gráfica de magnitud vs. días del segundo cluster, durante los primeros 50 días, se observa la misma tendencia mencionada anteriormente, sin embargo, a medida que pasa el tiempo se vuelven a registrar eventos de mayores magnitudes.

# %% [markdown]
# #### Pregunta 2.2

# %% [markdown]
# La expresión matemática de la ley de Omori es: n(t) = K/c+t, donde n corresponde al número de eventos sísmicos durante un tiempo t y K corresponde a la amplitud. Esta ley describe el comportamiento de las réplicas de un sismo con el paso del tiempo.

# %% [markdown]
# Para el cluster de enero 2014, la curva que más se acerca a los datos cumple la ecuación de la ley de Omori con c = 0.9 y k = 8.

# %%
t = []
n  = []
k = 8
c = 0.9

for sd in range(0,31):
    t.append(sd)
for df in range(0,31):
    n.append(k/(c+t[df]))

figu, axi = plt.subplots()

axi.plot(t,n,'b')
axi.lines[-1].set_linewidth(2)
axi.scatter(dias_en,num_sismos,color=('purple'),s=50,alpha=0.6)
plt.xlabel(r'$dias$', fontsize=15)
plt.ylabel(r'$Numero \ de \ sismos \ (n)$', fontsize=15)
plt.text(7, 11, "$\mathrm{Cluster \ enero \ 2014}$", fontsize=20, rotation='horizontal')

# %% [markdown]
# Para el cluster 2, los valores de c y k de la curva que más se ajusta a los datos son 4.5 y 320, respectivamente. Sin embargo, no alcanza a cubrir los eventos más frecuentes, los cuales corresponden a su vez con las magnitudes altas.

# %%
t2 = []
n2  = []
k = 320
c = 4.5

for ml in range(0,365):
    t2.append(ml)
for au in range(0,365):
    n2.append(k/(c+t2[au]))

fi, a = plt.subplots()
fi.set_size_inches(16,6)
a.plot(t2,n2,'b')
a.lines[-1].set_linewidth(2)
a.scatter(anhoc,total_sismos,color=('purple'),s=50,alpha=0.6)
plt.xlabel(r'$dias$', fontsize=15)
plt.ylabel(r'$Numero \ de \ sismos \ (n)$', fontsize=15)
plt.text(110, 165, "$\mathrm{Cluster \ abril \ 2014 \ a \ marzo \ 2015}$", fontsize=20, rotation='horizontal')

# %%
max_en = max(mag_enero); imax_en = mag_enero.index(max_en)
pmax_en = mag_enero[imax_en-1]
print 'Enero 2014:', max_en, max_en-pmax_en

max4 = max(mag4); imax4 = mag4.index(max4)
pmax4 = mag4[imax4-1]
print 'Abril 2014:', max4, max4-pmax4

max5 = max(mag5); imax5 = mag5.index(max5)
pmax5 = mag5[imax5-1]
print 'Mayo 2014:', max5, max5-pmax5

max6 = max(mag6); imax6 = mag6.index(max6)
pmax6 = mag6[imax6-1]
print 'Junio 2014:', max6, max6-pmax6

max7 = max(mag7); imax7 = mag7.index(max7)
pmax7 = mag7[imax7-1]
print 'Julio 2014:', max7, max7-pmax7

max8 = max(mag8); imax8 = mag8.index(max8)
pmax8 = mag8[imax8-1]
print 'Agosto 2014:', max8, max8-pmax8

max9 = max(mag9); imax9 = mag9.index(max9)
pmax9 = mag9[imax9-1]
print 'Septiembre 2014:', max9, max9-pmax9

max10 = max(mag10); imax10 = mag10.index(max10)
pmax10 = mag10[imax10-1]
print 'Octubre 2014:', max10, max10-pmax10

max11 = max(mag11); imax11 = mag11.index(max11)
pmax11 = mag11[imax11-1]
print 'Noviembre 2014:', max11, max11-pmax11

max12 = max(mag12); imax12 = mag12.index(max12)
pmax12 = mag12[imax12-1]
print 'Diciembre 2014:', max12, max12-pmax12

max1 = max(mag1); imax1 = mag1.index(max1)
pmax1 = mag1[imax1-1]
print 'Enero 2015:', max1, max1-pmax1

max2 = max(mag2); imax2 = mag2.index(max2)
pmax2 = mag2[imax2-1]
print 'Febrero 2015:', max2, max2-pmax2

max3 = max(mag3); imax3 = mag3.index(max3)
pmax3 = mag3[imax3-1]
print 'Marzo 2015:', max3, max3-pmax3
# Out:
# Enero 2014: 5.8 2.5
# Abril 2014: 8.2 5.4
# Mayo 2014: 5.5 2.6
# Junio 2014: 6.0 2.9
# Julio 2014: 5.6 2.3
# Agosto 2014: 4.7 2.0
# Septiembre 2014: 4.3 4.3
# Octubre 2014: 5.0 1.8
# Noviembre 2014: 5.1 2.4
# Diciembre 2014: 5.4 2.4
# Enero 2015: 4.4 1.6
# Febrero 2015: 4.5 4.5
# Marzo 2015: 4.3 4.3

# %% [markdown]
# Los datos anteriores muestran las magnitudes máximas para cada mes, seguidas por la diferencia entre esta y la anterior. Para el cluster 2, se puede observar que la ley de Bath, la cual dice que las magnitudes decaen aproximadamente 1.2 con el paso del tiempo, no se cumple porque las magnitudes decrecen mucho más rápido durante los primeros meses y luego siguen disminuyendo pero en una menor proporción. Igualmente se comportan los datos de magnitudes del cluster 1 pero en un rango temporal más corto.

# %% [markdown]
# De esta manera, se puede concluir que ni la ley de Omori ni la ley de Bath se cumplen para terremotos de magnitudes altas.

# %% [markdown]
# Si el primer cluster corresponde a un enjambre sismico y el segundo no, se podría decir que las leyes de Omori y de Bath no describirían el comportamiento del primero porque las magnitudes serían muy similares, no se encontraría una curva que se ajuste a los datos y no decaerían en 1.2 a medida que pase el tiempo. Mientras que para el cluster 2, si se acercan al comportamiento observado previamente.

# %% [markdown]
# Por otro lado, la sismicidad de febrero y marzo del 2015 corresponde a réplicas del sismo de magnitud 8.2 de abril 2014 porque cumple con las dos características fundamentales: se produce en la misma zona que el original y tiene una magnitud menor. Sin embargo, no está claro el límite temporal sobre el cual se pueden separar réplicas de nuevos eventos.
