# %% [markdown]
# ## Tarea 5 - Sismología

# %% [markdown]
# ### Universidad de Chile

# %% [markdown]
# ### Aura Cuervo Gómez

# %%
# %pylab inline
import numpy as np
import math as mt
from IPython.display import Image
from matplotlib import pyplot
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Cálculo de magnitud local (Ml)

# %% [markdown]
# A continuación se calculará la magnitud local de un evento, cuyo hipocentro está descrito por:

# %%
i = Image(filename='Captura.png')
i

# %% [markdown]
# Para realizar los calculos se tienen en cuenta las siguientes estaciones con su correspondiente ubicación y distancia hipocentral:

# %%
im = Image(filename='Captura2.png')
im

# %% [markdown]
# ### Estación MNMCX

# %%
datos1e = loadtxt('datos\DatosCalculoML\DatosWA\CX.MNMCX..HHE.D.2013.013.21.22.44.SAC.decowa.cut.dat')
vel1e = datos1e[:,1]
t1e = datos1e[:,0]

fig = plt.figure()
ax = fig.gca()
fig.set_size_inches(20,4)
plot(t1e, vel1e)
#ax.set_xticks(np.arange(0,190,5))
#ax.set_yticks(np.arange(-0.66,0.66,.05))
#xlim([0,190])
grid() 
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Desplazamiento \ en \ y \ (cm)$', fontsize=20)
title(r'$Sismograma \ E$', fontsize=20)

# %%
#Se seleccionaron los picos de amplitud máxima (0.49 m y -0.31 m), se convirtieron a mm y se calculó el promedio
peak_p1 = [490, 310]
A = np.mean(peak_p1)

# De acuerdo a la curva estandar, para una distancia hipocentral de 115 km: log (Ao) = -3.1
lA = mt.log10(A)
lAo = -3.1

ml = lA - lAo
print ml
# Out:
# 5.70205999133

# %%
datos1n = loadtxt('datos\DatosCalculoML\DatosWA\CX.MNMCX..HHN.D.2013.013.21.22.45.SAC.decowa.cut.dat')
vel1n = datos1n[:,1]
t1n = datos1n[:,0]

fig1 = plt.figure()
ax1 = fig1.gca()
fig1.set_size_inches(20,4)
plot(t1n, vel1n)
ax1.set_xticks(np.arange(75,90,5))
ax1.set_yticks(np.arange(-0.5,0.4,.05))
xlim([75,90])
grid() 
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Desplazamiento \ en \ y \ (m)$', fontsize=20)
title(r'$Sismograma \ N$', fontsize=20)

# %%
#Se seleccionaron los picos de amplitud máxima (0.40 m y -0.3 m), se convirtieron a mm y se calculó el promedio
peak_p1n = [400, 300]
An = np.mean(peak_p1n)

# De acuerdo a la curva estandar, para una distancia hipocentral de 115 km: log (Ao) = -3.1
lAn = mt.log10(An)
lAo = -3.1

mln = lAn - lAo
print mln
# Out:
# 5.64406804435

# %% [markdown]
# ### Estación PATA

# %%
datos1e = loadtxt('datos\DatosCalculoML\DatosWA\IQ.PATA..HHE.D.2013.013.21.22.42.SAC.decowa.cut.dat')
vel1e = datos1e[:,1]
t1e = datos1e[:,0]

fig2 = plt.figure()
ax2 = fig2.gca()
fig2.set_size_inches(20,8)
plot(t1e, vel1e)
ax2.set_xticks(np.arange(70,90,5))
ax2.set_yticks(np.arange(-0.7,0.7,.04))
xlim([70,90])
grid() 
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Desplazamiento \ en \ y \ (m)$', fontsize=20)
title(r'$Sismograma \ E$', fontsize=20)

# %%
#Se seleccionaron los picos de amplitud máxima (0.62 m y -0.61 m), se convirtieron a mm y se calculó el promedio
peak_p1e = [620, 610]
Ae = np.mean(peak_p1e)

# De acuerdo a la curva estandar, para una distancia hipocentral de 95 km: log (Ao) = -2.98
lAe = mt.log10(Ae)
lAo1 = -2.98

mle = lAe - lAo1
print mle
# Out:
# 5.76887511578

# %%
datos2n = loadtxt('datos\DatosCalculoML\DatosWA\IQ.PATA..HHN.D.2013.013.21.22.41.SAC.decowa.cut.dat')
v2n = datos2n[:,1]
t2n = datos2n[:,0]

fig3 = plt.figure()
ax3 = fig3.gca()
fig3.set_size_inches(20,7)
plot(t2n, v2n)
ax3.set_xticks(np.arange(70,85,5))
ax3.set_yticks(np.arange(-0.7,0.7,.04))
xlim([70,85])
grid() 
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Desplazamiento \ en \ y \ (m)$', fontsize=20)
title(r'$Sismograma \ N$', fontsize=20)

# %%
#Se seleccionaron los picos de amplitud máxima (0.50 m y -0.55 m), se convirtieron a mm y se calculó el promedio
peak_p2n = [500, 550]
A2n = np.mean(peak_p2n)

# De acuerdo a la curva estandar, para una distancia hipocentral de 95 km: log (Ao) = -2.98
lA2n = mt.log10(A2n)
lAo1 = -2.98

ml2n = lA2n - lAo1
print ml2n
# Out:
# 5.70015930341

# %% [markdown]
# ### Estación PSGCX

# %%
datos2e = loadtxt('datos\DatosCalculoML\DatosWA\CX.PSGCX..HHE.D.2013.013.21.22.45.SAC.decowa.cut.dat')
vel2e = datos2e[:,1]
t2e = datos2e[:,0]

fig4 = plt.figure()
ax4 = fig4.gca()
fig4.set_size_inches(20,8)
plot(t1e, vel1e)
ax4.set_xticks(np.arange(65,85,5))
ax4.set_yticks(np.arange(-0.7,0.7,.04))
xlim([65,85])
grid() 
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Desplazamiento \ en \ y \ (m)$', fontsize=20)
title(r'$Sismograma \ E$', fontsize=20)

# %%
#Se seleccionaron los picos de amplitud máxima (0.62 m y -0.61 m), se convirtieron a mm y se calculó el promedio
peak_p2e = [620, 610]
A2e = np.mean(peak_p2e)

# De acuerdo a la curva estandar, para una distancia hipocentral de 95 km: log (Ao) = -3.00
lA2e = mt.log10(A2e)
lAo2 = -3.00

ml2e = lA2e - lAo2
print ml2e
# Out:
# 5.78887511578

# %%
datos3n = loadtxt('datos\DatosCalculoML\DatosWA\CX.PSGCX..HHN.D.2013.013.21.22.41.SAC.decowa.cut.dat')
v3n = datos3n[:,1]
t3n = datos3n[:,0]

fig5 = plt.figure()
ax5 = fig5.gca()
fig5.set_size_inches(20,7)
plot(t3n, v3n)
ax5.set_xticks(np.arange(70,85,5))
ax5.set_yticks(np.arange(-0.15,0.15,.01))
xlim([70,85])
grid() 
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Desplazamiento \ en \ y \ (m)$', fontsize=20)
title(r'$Sismograma \ N$', fontsize=20)

# %%
#Se seleccionaron los picos de amplitud máxima (0.102 m y -0.145 m), se convirtieron a mm y se calculó el promedio
peak_p3n = [102, 145]
A3n = np.mean(peak_p3n)

# De acuerdo a la curva estandar, para una distancia hipocentral de 95 km: log (Ao) = -3.00
lA3n = mt.log10(A3n)
lAo2 = -3.00

ml3n = lA3n - lAo2
print ml3n
# Out:
# 5.0916669576

# %% [markdown]
# ### Estación UNAP

# %%
datos3e = loadtxt('datos\DatosCalculoML\DatosWA\IQ.UNAP..HHE.D.2013.013.21.22.41.SAC.decowa.cut.dat')
v3e = datos3e[:,1]
t3e= datos3e[:,0]

fig6 = plt.figure()
ax6 = fig6.gca()
fig6.set_size_inches(20,8)
plot(t3e, v3e)
ax6.set_xticks(np.arange(65,85,5))
ax6.set_yticks(np.arange(-0.3,0.3,.02))
xlim([65,85])
grid() 
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Desplazamiento \ en \ y \ (m)$', fontsize=20)
title(r'$Sismograma \ E$', fontsize=20)

# %%
#Se seleccionaron los picos de amplitud máxima (0.28 m y -0.20 m), se convirtieron a mm y se calculó el promedio
peak_p4e = [280, 200]
A4e = np.mean(peak_p4e)

# De acuerdo a la curva estandar, para una distancia hipocentral de 85 km: log (Ao) = -2.94
lA4e = mt.log10(A4e)
lAo3 = -2.94

ml4e = lA4e - lAo3
print ml4e
# Out:
# 5.32021124171

# %%
datos4n = loadtxt('datos\DatosCalculoML\DatosWA\IQ.UNAP..HHN.D.2013.013.21.22.43.SAC.decowa.cut.dat')
v4n = datos4n[:,1]
t4n = datos4n[:,0]

fig7 = plt.figure()
ax7 = fig7.gca()
fig7.set_size_inches(20,7)
plot(t4n, v4n)
ax7.set_xticks(np.arange(70,85,5))
ax7.set_yticks(np.arange(-0.3,0.3,.02))
xlim([70,85])
grid() 
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Desplazamiento \ en \ y \ (m)$', fontsize=20)
title(r'$Sismograma \ N$', fontsize=20)

# %%
#Se seleccionaron los picos de amplitud máxima (0.28 m y -0.27 m), se convirtieron a mm y se calculó el promedio
peak_p4n= [280, 270]
A4n = np.mean(peak_p4n)

# De acuerdo a la curva estandar, para una distancia hipocentral de 85 km: log (Ao) = -2.94
lA4n = mt.log10(A4n)

ml4n = lA4n - lAo3
print ml4n
# Out:
# 5.37933269383

# %% [markdown]
# ### Estación PB07

# %%
datos4e = loadtxt('datos\DatosCalculoML\DatosWA\CX.PB07..HHE.D.2013.013.21.22.50.SAC.decowa.cut.dat')
v4e = datos4e[:,1]
t4e= datos4e[:,0]

fig8 = plt.figure()
ax8 = fig8.gca()
fig8.set_size_inches(20,8)
plot(t4e, v4e)
ax8.set_xticks(np.arange(75,100,5))
ax8.set_yticks(np.arange(-0.2,0.2,.01))
xlim([75,100])
grid() 
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Desplazamiento \ en \ y \ (m)$', fontsize=20)
title(r'$Sismograma \ E$', fontsize=20)

# %%
#Se seleccionaron los picos de amplitud máxima (0.155 m y -0.15 m) se convirtieron a mm y se calculó el promedio
peak_p5e = [155,150]
A5e = np.mean(peak_p5e)

# De acuerdo a la curva estandar, para una distancia hipocentral de 185km: log (Ao) = -3.45
lA5e = mt.log10(A5e)
lAo4 = -3.45
ml5e = lA5e - lAo4
print ml5e
# Out:
# 5.63326984368

# %%
datos5n = loadtxt('datos\DatosCalculoML\DatosWA\CX.PB07..HHN.D.2013.013.21.22.50.SAC.decowa.cut.dat')
v5n = datos5n[:,1]
t5n = datos5n[:,0]

fig9 = plt.figure()
ax9 = fig9.gca()
fig9.set_size_inches(20,7)
plot(t5n, v5n)
ax9.set_xticks(np.arange(80,95,5))
ax9.set_yticks(np.arange(-0.15,0.15,.01))
xlim([80,95])
grid() 
xlabel(r'$t (s)$', fontsize=20)
ylabel(r'$Desplazamiento \ en \ y \ (m)$', fontsize=20)
title(r'$Sismograma \ N$', fontsize=20)

# %%
#Se seleccionaron los picos de amplitud máxima (0.085 m y -0.12 m) se convirtieron a mm y se calculó el promedio
peak_p5n = [85,120]
A5n = np.mean(peak_p5n)

# De acuerdo a la curva estandar, para una distancia hipocentral de 185km: log (Ao) = -3.45
lA5n = mt.log10(A5n)

ml5n = lA5n - lAo4
print ml5n
# Out:
# 5.46072386539

# %%
mls = [ml, mln, mle, ml2n, ml2e, ml3n, ml4e, ml4n, ml5n, ml5e]
ml_f = np.mean(mls)
print ml_f
# Out:
# 5.54892421728

# %% [markdown]
# #### La magnitud local promedio de este evento es 5.55

# %% [markdown]
# ### Cálculo de magnitud de momento

# %% [markdown]
# ### Estación MNMCX

# %%
date = loadtxt('datos\DatosCalculoMW\DatosTF\CX.MNMCX..HHE.D.2013.013.21.22.44.SAC.deco.TF.dat')
ae = date[:,1]
fe = date[:,0]

figa = plt.figure()
axa = figa.gca()
figa.set_size_inches(15,7)
pyplot.plot(fe, ae)
pyplot.yscale('log')
pyplot.xscale('log')
grid() 
xlabel(r'$log \ (f)$', fontsize=20)
ylabel(r'$log \ (A)$', fontsize=20)
title(r'$Sismograma \ E$', fontsize=20)

# %%
datn = loadtxt('datos\DatosCalculoMW\DatosTF\CX.MNMCX..HHN.D.2013.013.21.22.45.SAC.deco.TF.dat')
an = datn[:,1]
fn = datn[:,0]

figb = plt.figure()
axb = figb.gca()
figb.set_size_inches(15,7)
pyplot.plot(fn, an)
pyplot.yscale('log')
pyplot.xscale('log')
grid() 
xlabel(r'$log \ (f)$', fontsize=20)
ylabel(r'$log \ (A)$', fontsize=20)
title(r'$Sismograma \ N$', fontsize=20)

# %%
datz = loadtxt('datos\DatosCalculoMW\DatosTF\CX.MNMCX..HHZ.D.2013.013.21.22.47.SAC.deco.TF.dat')
az = datz[:,1]
fz = datz[:,0]

figc = plt.figure()
axc = figc.gca()
figc.set_size_inches(15,7)
pyplot.plot(fz, az)
pyplot.yscale('log')
pyplot.xscale('log')
grid() 
xlabel(r'$log \ (f)$', fontsize=20)
ylabel(r'$log \ (A)$', fontsize=20)
title(r'$Sismograma \ Z$', fontsize=20)

# %%
#De acuerdo a las gráficas anteriores, el valor del plateau es 0.0002 m (E), 0.00004 (N) y 0.0001 (Z)
ple = 0.0002 #m
pln = 0.00004
plz = 0.0001

pl_s = pow(ple,2)+pow(pln,2)+pow(plz,2)
pl = sqrt(pl_s)

#Como el sismo se originó a 90 km de profundidad, los datos de velocidad de la onda s y densidad que se deben emplear son:
vs = 4780 #m/s
d = 3380 #kg/m3
r = 113700 #m

c1 = 4*np.pi*d*(pow(vs,3))
c = 0.67*2

Mo = ((c1*r*pl)/c)
Mw = (0.6666666667*(mt.log10(Mo)))-6.07
print Mw
# Out:
# 5.23092718141

# %% [markdown]
# ### Estación PATA

# %%
date1 = loadtxt('datos\DatosCalculoMW\DatosTF\IQ.PATA..HHE.D.2013.013.21.22.42.SAC.deco.TF.dat')
ae1 = date1[:,1]
fe1 = date1[:,0]

figd = plt.figure()
axd = figd.gca()
figd.set_size_inches(15,7)
pyplot.plot(fe1, ae1)
pyplot.yscale('log')
pyplot.xscale('log')
grid() 
xlabel(r'$log \ (f)$', fontsize=20)
ylabel(r'$log \ (A)$', fontsize=20)
title(r'$Sismograma \ E$', fontsize=20)

# %%
datn1 = loadtxt('datos\DatosCalculoMW\DatosTF\IQ.PATA..HHN.D.2013.013.21.22.41.SAC.deco.TF.dat')
an1 = datn1[:,1]
fn1 = datn1[:,0]

fige = plt.figure()
axe = fige.gca()
fige.set_size_inches(15,7)
pyplot.plot(fn1, an1)
pyplot.yscale('log')
pyplot.xscale('log')
grid() 
xlabel(r'$log \ (f)$', fontsize=20)
ylabel(r'$log \ (A)$', fontsize=20)
title(r'$Sismograma \ N$', fontsize=20)

# %%
datz1 = loadtxt('datos\DatosCalculoMW\DatosTF\IQ.PATA..HHZ.D.2013.013.21.22.44.SAC.deco.TF.dat')
az1 = datz1[:,1]
fz1 = datz1[:,0]

figf = plt.figure()
axf = figf.gca()
figf.set_size_inches(15,7)
pyplot.plot(fz1, az1)
pyplot.yscale('log')
pyplot.xscale('log')
grid() 
xlabel(r'$log \ (f)$', fontsize=20)
ylabel(r'$log \ (A)$', fontsize=20)
title(r'$Sismograma \ Z$', fontsize=20)

# %%
#De acuerdo a las gráficas anteriores, el valor del plateau es 0.0002 m (E), 0.00004 (N) y 0.0001 (Z)
ple1 = 0.0004 #m
pln1 = 0.0003
plz1 = 0.0001

pl_s1 = pow(ple1,2)+pow(pln1,2)+pow(plz1,2)
pl1 = sqrt(pl_s1)

#Como el sismo se originó a 90 km de profundidad, los datos de velocidad de la onda s y densidad que se deben emplear son:
vs = 4780 #m/s
d = 3380 #kg/m3
r = 93000 #m

Mo1 = ((c1*r*pl1)/c)
Mw1 = (0.6666666667*(mt.log10(Mo1)))-6.07
print Mw1
# Out:
# 5.40685005278

# %% [markdown]
# ### Estación PSGCX

# %%
date2 = loadtxt('datos\DatosCalculoMW\DatosTF\CX.PSGCX..HHE.D.2013.013.21.22.45.SAC.deco.TF.dat')
ae2 = date2[:,1]
fe2 = date2[:,0]

figg = plt.figure()
axg = figg.gca()
figg.set_size_inches(15,7)
pyplot.plot(fe2, ae2)
pyplot.yscale('log')
pyplot.xscale('log')
grid() 
xlabel(r'$log \ (f)$', fontsize=20)
ylabel(r'$log \ (A)$', fontsize=20)
title(r'$Sismograma \ E$', fontsize=20)

# %%
datn2 = loadtxt('datos\DatosCalculoMW\DatosTF\CX.PSGCX..HHN.D.2013.013.21.22.41.SAC.deco.TF.dat')
an2 = datn2[:,1]
fn2 = datn2[:,0]

figh = plt.figure()
axh = figh.gca()
figh.set_size_inches(15,7)
pyplot.plot(fn2, an2)
pyplot.yscale('log')
pyplot.xscale('log')
grid() 
xlabel(r'$log \ (f)$', fontsize=20)
ylabel(r'$log \ (A)$', fontsize=20)
title(r'$Sismograma \ N$', fontsize=20)

# %%
datz2 = loadtxt('datos\DatosCalculoMW\DatosTF\CX.PSGCX..HHZ.D.2013.013.21.22.39.SAC.deco.TF.dat')
az2 = datz2[:,1]
fz2 = datz2[:,0]

figj = plt.figure()
axj = figj.gca()
figj.set_size_inches(15,7)
pyplot.plot(fz2, az2)
pyplot.yscale('log')
pyplot.xscale('log')
grid() 
xlabel(r'$log \ (f)$', fontsize=20)
ylabel(r'$log \ (A)$', fontsize=20)
title(r'$Sismograma \ Z$', fontsize=20)

# %%
#De acuerdo a las gráficas anteriores, el valor del plateau es 0.0002 m (E), 0.00004 (N) y 0.0001 (Z)
ple2 = 0.0002 #m
pln2 = 0.0002
plz2 = 0.00006

pl_s2 = pow(ple2,2)+pow(pln2,2)+pow(plz2,2)
pl2 = sqrt(pl_s2)

#Como el sismo se originó a 90 km de profundidad, los datos de velocidad de la onda s y densidad que se deben emplear son:
vs = 4780 #m/s
d = 3380 #kg/m3
r = 100700 #m

Mo2 = ((c1*r*pl2)/c)
Mw2 = (0.6666666667*(mt.log10(Mo2)))-6.07
print Mw2
# Out:
# 5.26562537726

# %% [markdown]
# ### Estación UNAP

# %%
date3 = loadtxt('datos\DatosCalculoMW\DatosTF\IQ.UNAP..HHE.D.2013.013.21.22.41.SAC.deco.TF.dat')
ae3 = date3[:,1]
fe3 = date3[:,0]

figk = plt.figure()
axk = figk.gca()
figk.set_size_inches(15,7)
pyplot.plot(fe3, ae3)
pyplot.yscale('log')
pyplot.xscale('log')
grid() 
xlabel(r'$log \ (f)$', fontsize=20)
ylabel(r'$log \ (A)$', fontsize=20)
title(r'$Sismograma \ E$', fontsize=20)

# %%
datn3 = loadtxt('datos\DatosCalculoMW\DatosTF\IQ.UNAP..HHN.D.2013.013.21.22.43.SAC.deco.TF.dat')
an3 = datn3[:,1]
fn3 = datn3[:,0]

figl = plt.figure()
axl = figl.gca()
figl.set_size_inches(15,7)
pyplot.plot(fn3, an3)
pyplot.yscale('log')
pyplot.xscale('log')
grid() 
xlabel(r'$log \ (f)$', fontsize=20)
ylabel(r'$log \ (A)$', fontsize=20)
title(r'$Sismograma \ N$', fontsize=20)

# %%
datz3 = loadtxt('datos\DatosCalculoMW\DatosTF\IQ.UNAP..HHZ.D.2013.013.21.22.40.SAC.deco.TF.dat')
az3 = datz3[:,1]
fz3 = datz3[:,0]

figm = plt.figure()
axm = figm.gca()
figm.set_size_inches(15,7)
pyplot.plot(fz3, az3)
pyplot.yscale('log')
pyplot.xscale('log')
grid() 
xlabel(r'$log \ (f)$', fontsize=20)
ylabel(r'$log \ (A)$', fontsize=20)
title(r'$Sismograma \ Z$', fontsize=20)

# %%
#De acuerdo a las gráficas anteriores, el valor del plateau es 0.0002 m (E), 0.00004 (N) y 0.0001 (Z)
ple3 = 0.0002 #m
pln3 = 0.0003
plz3 = 0.0002

pl_s3 = pow(ple3,2)+pow(pln3,2)+pow(plz3,2)
pl3 = sqrt(pl_s3)

#Como el sismo se originó a 90 km de profundidad, los datos de velocidad de la onda s y densidad que se deben emplear son:
vs = 4780 #m/s
d = 3380 #kg/m3
r = 84800 #m

Mo3 = ((c1*r*pl3)/c)
Mw3 = (0.6666666667*(mt.log10(Mo3)))-6.07
print Mw3
# Out:
# 5.31861717971

# %% [markdown]
# ### Estación PB07

# %%
date4 = loadtxt('datos\DatosCalculoMW\DatosTF\CX.PB07..HHE.D.2013.013.21.22.50.SAC.deco.TF.dat')
ae4 = date4[:,1]
fe4 = date4[:,0]

fign = plt.figure()
axn = fign.gca()
fign.set_size_inches(15,7)
pyplot.plot(fe4, ae4)
pyplot.yscale('log')
pyplot.xscale('log')
grid() 
xlabel(r'$log \ (f)$', fontsize=20)
ylabel(r'$log \ (A)$', fontsize=20)
title(r'$Sismograma \ E$', fontsize=20)

# %%
datn4 = loadtxt('datos\DatosCalculoMW\DatosTF\CX.PB07..HHN.D.2013.013.21.22.50.SAC.deco.TF.dat')
an4 = datn4[:,1]
fn4 = datn4[:,0]

figo = plt.figure()
axo = figo.gca()
figo.set_size_inches(15,7)
pyplot.plot(fn4, an4)
pyplot.yscale('log')
pyplot.xscale('log')
grid() 
xlabel(r'$log \ (f)$', fontsize=20)
ylabel(r'$log \ (A)$', fontsize=20)
title(r'$Sismograma \ N$', fontsize=20)

# %%
datz4 = loadtxt('datos\DatosCalculoMW\DatosTF\CX.PB07..HHZ.D.2013.013.21.22.53.SAC.deco.TF.dat')
az4 = datz4[:,1]
fz4 = datz4[:,0]

figp = plt.figure()
axp = figp.gca()
figp.set_size_inches(15,7)
pyplot.plot(fz4, az4)
pyplot.yscale('log')
pyplot.xscale('log')
grid() 
xlabel(r'$log \ (f)$', fontsize=20)
ylabel(r'$log \ (A)$', fontsize=20)
title(r'$Sismograma \ Z$', fontsize=20)

# %%
#De acuerdo a las gráficas anteriores, el valor del plateau es 0.0002 m (E), 0.00004 (N) y 0.0001 (Z)
ple4 = 0.00007 #m
pln4 = 0.0001
plz4 = 0.0001

pl_s4 = pow(ple4,2)+pow(pln4,2)+pow(plz4,2)
pl4 = sqrt(pl_s4)

#Como el sismo se originó a 90 km de profundidad, los datos de velocidad de la onda s y densidad que se deben emplear son:
vs = 4780 #m/s
d = 3380 #kg/m3
r = 185900 #m

Mo4 = ((c1*r*pl4)/c)
Mw4 = (0.6666666667*(mt.log10(Mo4)))-6.07
print Mw4
# Out:
# 5.26778967996

# %%
Mws = [Mw, Mw1, Mw2, Mw3, Mw4]
Mwf = np.mean(Mws)
print Mwf
# Out:
# 5.29796189423

# %% [markdown]
# #### La magnitud de momento de este evento es 5.29
